# %% [markdown]
# # ButtonTactics Pro — Protótipo
# **Bloco 1:** Preparação dos dados
# **Bloco 2:** Visualização interativa com slider de tempo

# %% [markdown]
# ## Instalação das dependências

# %% [markdown]
# ## Bloco 1 — Preparação dos dados

# %%
from data_pipe.data_prep import prepare, frame_ids, get_frame

# Carrega os dados de exemplo da Metrica Sports via kloppy
# limit=None carrega a partida inteira (~2000 frames por período)
# Para testes rápidos use limit=500
df = prepare(
    match_id=1,       # 1 ou 2 (Metrica open data)
    limit=500,        # None = partida completa
    smooth_window=3   # janela do filtro de suavização (frames)
)

print(f'Frames carregados : {len(frame_ids(df))}')
print(f'Linhas no DataFrame: {len(df)}')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data_pipe.data_prep import prepare, frame_ids, get_frame
#       2
#       3 # Carrega os dados de exemplo da Metrica Sports via kloppy
#       4 # limit=None carrega a partida inteira (~2000 frames por período)
#
# File ~\OneDrive\Documentos\Unisinos\SIstema de Análise de análise Espaço-Temporal do Comportamento Tático no Futebol\data_pipe\data_prep.py:12
#      10 import pandas as pd
#      11 from kloppy import metrica
# ---> 12 from vis.colors import PITCH_LENGTH, PITCH_WIDTH
#      14 # ── Carregamento ──────────────────────────────────────────────────────────────
#      16 def load_dataset(match_id: int = 1, limit: int | None = None) -> object:
#
# File ~\OneDrive\Documentos\Unisinos\SIstema de Análise de análise Espaço-Temporal do Comportamento Tático no Futebol\vis\__init__.py:1
# ----> 1 from .player import interactive, snapshot
#
# File ~\OneDrive\Documentos\Unisinos\SIstema de Análise de análise Espaço-Temporal do Comportamento Tático no Futebol\vis\player.py:11
#       8 import matplotlib.widgets as widgets
#       9 from matplotlib.animation import FuncAnimation
# ---> 11 from data_pipe.data_prep import get_frame, frame_ids
#      12 from .colors import COLORS, PITCH_KWARGS, SPEEDS, BASE_INTERVAL
#      13 from .layers import draw_field, draw_frame
#
# ImportError: cannot import name 'get_frame' from partially initialized module 'data_pipe.data_prep' (most likely due to a circular import) (C:\Users\kauan\OneDrive\Documentos\Unisinos\SIstema de Análise de análise Espaço-Temporal do Comportamento Tático no Futebol\data_pipe\data_prep.py)

# %% [markdown]
# ## Bloco 2 — Visualização interativa

# %%
# Para o slider funcionar no Jupyter é necessário o backend interativo
# No VS Code / JupyterLab use: %matplotlib widget
# No Jupyter classic use:      %matplotlib tk
# %matplotlib widget

import vis
from vis.player import interactive, snapshot

interactive(
    df,
    show_skeleton=True,   # linhas entre vizinhos mais próximos
    show_delaunay=True,   # Shape Graph (Triangulação de Delaunay)
    show_hull=True        # polígono convexo de cada time
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       5
#       6 import vis
#       7 from vis.player import interactive, snapshot
#       8
# ----> 9 interactive(
#      10     df,
#      11     show_skeleton=True,   # linhas entre vizinhos mais próximos
#      12     show_delaunay=True,   # Shape Graph (Triangulação de Delaunay)
#
# File c:\Users\kauan\OneDrive\Documentos\Unisinos\SIstema de Análise de análise Espaço-Temporal do Comportamento Tático no Futebol\vis\player.py:3, in interactive(df, show_skeleton, show_delaunay, show_hull)
#       1 def interactive(df, show_skeleton=True, show_delaunay=True, show_hull=True):
# ----> 3     ids = frame_ids(df)
#       4     n   = len(ids)
#       6     fig, ax = plt.subplots(figsize=(14, 9))
#
# NameError: name 'frame_ids' is not defined

# %% [markdown]
# ## Extra — Exportar um frame como imagem estática

# %%
# %matplotlib inline
from apagr.viz import snapshot

ids = frame_ids(df)

# Salva o frame do minuto ~2 como PNG
snapshot(df, ids[50], path='frame_50.png')
# Out:
# Salvo em frame_50.png
